# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/datascience/blob/main/15.%20(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%20%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80_%EB%B3%B4%EC%8A%A4%ED%84%B4%20%EC%A3%BC%ED%83%9D%20%EA%B0%80%EA%B2%A9%20%EC%98%88%EC%B8%A1%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. 데이터 설명

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
data = pd.read_csv('./')
data.head()

# %% [markdown]
# #2. 단순선형회귀

# %%
x = data.loc[:, ['']]
y = data.loc[:,'MEDV']

# %%
# 선형회귀 모델이 주어진 데이터에 적절한 모델인지 그림으로 확인한다.(특성 한가지만)
import matplotlib.pyplot as plt

# %% [markdown]
# #모델 만들기

# %% [markdown]
# #3. 다중 선형회귀 모델
# > 주택 가격과 관련이 높은 특성들을 모두 활용해보자!

# %% [markdown]
# # 데이터 특징들 간의 상관 관계를 처리하고 data_f에 저장하기
# *    '피어슨의 상관 계수' 를 통해 boston 데이터의 특징들 간 상관관계를 구하고 data_f에 저장
# * 피어슨(pearson) 상관 계수 : 두 변수 간의 관련성을 구하기 위해 상관 관계 분석에 보편적으로 이용 범위는 -1<=피어슨<=1 이며, 1(또는 -1)과 가까울수록 관련성이 높고 0과 가까울수록 관련성이 낮다

# %% [markdown]
# #히트맵
# > 두 변수간의 상관관계를 컬러로 변환시켜 열 분포 형태로 시각적인 분석을 가능하게 함

# %% [markdown]
# # 데이터 특징들 간의 피어슨 상관관계를 그래프로 보여주는 코드(히트맵) 입력하기
#
# ![image.png](data:image/png;base64,...)

# %%
fig, axs = plt.subplots(figsize=(8,8), ncols=2, nrows=2)

lm_features = ['','','','']

for i, feature in enumerate(lm_features):
    row = int(i/2) # 2행
    col = i%2

    # sns.regplot : 회귀직선을 그려줌
    sns.regplot(x=feature, y='MEDV', data=data, ax=axs[row][col])

# %% [markdown]
# ### 집값 상승과 상관관계가 가장 높은 것 : RM
# ### 집값 하락과 상관관계가 가장 높은 것 : LSTAT

# %%
X = data.iloc[:, :-1]  #특성(feature)
Y = data.iloc[:,-1]  #레이블

# %%
x_new = [[0.00632, 18, 2.31, 0, 0.538, 6.575, 65.2, 4.09, 1, 296, 15.3, 396.9, 4.98]]

# %% [markdown]
# #4. 성능평가

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#MAE = 모델의 예측값과 실제값 차이의 절대값의 평균
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#MSE = 모델의 예측값과 실제값 차이의 제곱합
#RMSE = MSE에 루트 씌운거, 특이치에 강하다
from sklearn.metrics import mean_squared_error
