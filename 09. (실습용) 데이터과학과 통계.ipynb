# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/datascience/blob/main/09.%20(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%20%EB%8D%B0%EC%9D%B4%ED%84%B0%EA%B3%BC%ED%95%99%EA%B3%BC%20%ED%86%B5%EA%B3%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 데이터 탐색
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 평균을 산출하는데 이용한 표본과 용어에서 나오는
# 차이를 명확하게 인지하지 못하고 단순히 드러나는
# 평균값만을 받아들일 경우, 통계가 나타내는
#  진실로부터 멀어질 수 있다.

# %% [markdown]
# ### 1. 데이터 다루기
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2. 대푯값
#
#
# > 대푯값 : 데이터 전체의 중심 위치를 나타내 주는 값
# ex ) 평균값, 중앙값, 최빈값 등등

# %%
# 내장 함수로 평균 구하기
data = [1, 2, 3, 4, 5]
avg =
print("평균 : ", avg)

# %% [markdown]
# > 데이터에 극적인 값이 포함되어 있더라도 영향을 적게 받는 대푯값 - 중앙값
#
#
#
# > 범주형 데이터를 분석할 때는 최빈값이 유용

# %%
# 중앙값 구하기
print("중앙값 : ", )

# %%
# 최빈값 구하기
print('최빈값 : ', )

# %%
# 개수 세기

# %%
# 다양한 통계 정보를 요약해주는 describe() 함수

# %%
#만약 문자형 데이터라면
df2 = pd.DataFrame(['a', 'b', 'c', 'a', 'z', 'n', 't'], columns = ['string'])

# %% [markdown]
# #### 실습1. 청주의 기온 데이터 다루기

# %%
import pandas as pd
data = pd.read_csv()
data.head()

# %%
# 평균기온만 뽑아서 출력하기

# %%
#2000년부터 2025년 현재까지 평균기온 구하기

# %%
#청주의 평균기온이 가장 높았던 날은?
#정렬하기

# %%
#내림차순으로

# %% [markdown]
# ### 결론 - 2000년대에 들어 가장 더웠던 날은 24년도 8월입니다.

# %%
#20년도 8월과 24년도 8월 기온차이 그래프로 나타내보기
