# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/datascience/blob/main/13.%20(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%20%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%20%EB%A7%9B%EB%B3%B4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 도미와 빙어 분류하기
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Q. 사람은 도미와 빙어를 외형으로 쉽게 구분할 수 있지만 기계가 이 둘을 구분하려면?

# %%
#1. 데이터 불러오기
import pandas as pd
data = pd.read_excel('./fish.xlsx')
data.head()

# %%
import matplotlib.pyplot as plt

#산점도 그리는 코드
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
#2. 기계학습(머신러닝)을 위한 모듈 불러오기

# %% [markdown]
# ### K-최근접 이웃 알고리즘(KNN)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####사이킷런에서는 기본값으로 k = 5

# %%
#3. 훈련데이터와 테스트데이터 나누기

# %%
a = X_train.loc[:,['길이']]
b = X_train.loc[:,['무게']]
at = X_test.loc[:,['길이']]
bt = X_test.loc[:,['무게']]
#훈련데이터 구분하여 산점도 그리는 코드
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
#경고문구 무시하기
import warnings
warnings.filterwarnings(action='ignore')

# %%
#예측하기

# %%
#수상한 데이터 확인하기
x = data['길이']
y = data['무게']
plt.scatter(x, y)
#예측해야하는 값 세모 표시로 나타내보기
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %% [markdown]
# ### 두 특성의 스케일이 다르기 때문에 거리기반의 알고리즘을 사용하면 제대로 예측할 수 없음!
# #### 보통 표준점수를 사용하여 데이터 전처리를 실행

# %%
#표준점수 = 각 데이터가 원점에서 몇 표준편차만큼 떨어져 있는지를 나타내는 값
#넘파이 라이브러리 불러들이기

mean = np.mean(X_train, axis=0)
std = np.std(X_train, axis=0)

train_scaled = (X_train - mean) / std

# %%
#표준점수 적용한 산점도 그래프 그리기
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
#다시 모델 훈련

# %%
#다시 예측
