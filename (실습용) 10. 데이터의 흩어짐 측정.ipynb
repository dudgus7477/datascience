# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/datascience/blob/main/(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%2010.%20%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%9D%98%20%ED%9D%A9%EC%96%B4%EC%A7%90%20%EC%B8%A1%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## * 판다스 통계 함수
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #1. 산포도

# %% [markdown]
# case 1. 15, 15, 15, 15
# case 2. 0, 0, 30, 30
# 두 개의 케이스 모두 평균 15도, 평균 기온이 동일하므로 두 기간 동안 온도가 비슷했다고 이야기할 수 있을까?
#
#
# > 분포 상태를 확인해야한다!
#
# ### **산포도 : 대푯값을 중심으로 데이터들이 흩어져 있는 정도, 즉 데이터가 얼마나 퍼져 있나를 하나의 수로 나타낸 값**
# 보통 0에 근접한 값이면 데이터가 거의 흩어져 있지 않음을 뜻함.

# %%
import pandas as pd

df = pd.DataFrame({'연도' : [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2024, 2025], '인구수': [831912, 835197, 835590, 837749, 839428,857527, 860831, 849573, 853187, 882008]})
df

# %%
#산점도 그리기
import matplotlib.pyplot as plt

# %%
# 산포도 나타내는 가장 간단한 통계치
print("범위:", )

# %%
# 상위 25%에 해당하는 값과 하위 25%에 해당하는 값 차이(사분위간 범위)
print("사분위간 범위:", )

# %%
#분산, 표준편차
print("분산:", )
print("표준편차:", )

# %% [markdown]
# 편차 - 데이터 셋의 각 데이터 값에서 평균을 뺀 값
# 클수록 평균으로부터 멀리 떨어져있음.
# 분산 - 각 편차를 제곱하여 평균을 구한 값
# 표준편차 - 원래 데이터와 동일한 단위 가짐.

# %% [markdown]
# # 2. 통계적 추정

# %% [markdown]
# ### 들어가기 전에, 한글 폰트 설정해주기
#
# #### 코랩에서 한글 폰트 설정
# 1) 한글 폰트 코드 실행
#
# ```
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# ```
#
# 2) 런타임 - 런타임 다시시작
#
# 3) 글꼴 지정 명령어
#
# ```
# plt.rc('font', family='NanumGothic')
# ```

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# 청주 인구수의 표준편차가 14864라는 것은 어떤 의미가 있는지 직관적으로 이해하기 쉽지 않다.
#
# ✅2025년도가 최근 10년치를 기준으로 대략 어디 즈음에 위치해 있을까?
#
# ✅2023년도 청주시의 인구수를 통계치를 이용해 추측한다면?
#
# ❗확률 현상으로 바라보는 관점이 필요.(정확히 예측할 수 없는 변동 가능한 값으로 바라보기.)

# %%
# 인구수 분포와 정규분포를 그래프로 그려보자.
from scipy import stats #사이파이 라이브러리
import seaborn as sns
import numpy as np
plt.rc('font', family='NanumGothic')

# 평균과 표준편차 계산
avg =
std =

# Seaborn displot (히스토그램 + KDE:부드러운 형태의 분포 곡선)
sns.displot(df['인구수'], kde=True, stat="density", bins=10) # bin의 개수 지정

# 정규분포 곡선 추가
x = np.linspace(min(df['인구수']), max(df['인구수']), 100)
p =

# 기존 displot과 정규분포를 함께 표시
plt.plot(, 'r', linestyle='dashed', label="정규분포 곡선")
plt.xlabel()
plt.title()
plt.legend()
plt.show()

# %% [markdown]
# ## [통계적 추정 예시]
#
# ✔️평균 - 848300
# ✔️표준편차 - 15619
# 파란선은 인구 데이터의 분포이다.
#
#
# > 인구 확률분포를 정규분포로 가정하면, 2025년 인구수(882008)는 평균으로부터 2α(33708)이상 벗어나 있으므로, 상위 3% 정도 즈음에 위치해있다고 통계적으로 추정할 수 있다.
#
#
# > 또한, 2023년의 인구수는 832681부터 863919일 가능성이 대략 70%라고도 추정할 수 있다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 실제 - 852, 189명

# %% [markdown]
# ### 실습1. 3/28일 평균기온 추정하기

# %% [markdown]
# #####기상청은 기상자료개방포털 홈페이지를 통해 기상 관련 데이터를 무료로 개방한다.
#
# >데이터 출처 : https://data.kma.go.kr
#
# #####'기후통계분석-> 기온분석'
