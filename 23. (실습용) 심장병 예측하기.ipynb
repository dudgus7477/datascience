# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/datascience/blob/main/23.%20(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%20%EC%8B%AC%EC%9E%A5%EB%B3%91%20%EC%98%88%EC%B8%A1%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #데이터 준비하기
# - 캐글 : https://www.kaggle.com/datasets/rashikrahmanpritom/heart-attack-analysis-prediction-dataset
# - 심장병 데이터 셋

# %%
#라이브러리 설치
from keras.models import Sequential
from keras.layers import Dense

# %%
#데이터 표현하기
import pandas as pd
df = pd.read_csv('')
df.head(10)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#그래프형으로 데이터 표현하기
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,14))
sns.heatmap(df.corr(), annot=True, linewidths=0.1, vmax=0.5, cmap='Blues')
plt.show()

# %% [markdown]
# #모델 설계하기

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
x = df.iloc[:, :-1] #outcome제외하고 모두
y = df.iloc[:, -1] # outcome만

# %% [markdown]
# #X값 선정하기(3개 이상)
#  : 가설세우기

# %%
#나이
import seaborn as sns
plt.figure(figsize=(12,6))
sns.barplot(x="age", y="output", data=df) #검정 선은 신뢰구간

# %%
#가슴통증유형과 발병여부 관계만 따로 살펴보자
sns.catplot(x='output', y='cp', data=df, kind='violin')

# %%
#최대심박수
plt.figure(figsize=(12,6))
plt.hist(x=[df.thalachh[df.output==0], df.thalachh[df.output==1]], bins=30, histtype='barstacked', label=['normal', 'heart'])
plt.xlabel('thalachh')
plt.legend()

# %%
X = df[[]]
Y = df.iloc[:, -1] # outcome만

# %%
model = Sequential()
model.add(Dense(12, input_dim= , activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X,Y,epochs=200,batch_size=10)

# %%
print('Accuracy',model.evaluate(X,Y)[1])
