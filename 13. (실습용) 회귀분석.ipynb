# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/datascience/blob/main/13.%20(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%20%ED%9A%8C%EA%B7%80%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. 회귀분석
# >회귀분석이란?
# - 하나 이상의 독립변수들이 종속변수에 미치는 영향을 추정하는 통계 기법이다.
# ###### 그 중 단순선형회귀모형은 하나의 x가 y에 미치는 영향을 추정하며 1차 함수 관계로 나타낼 수 있다.
# ##### y = Wx+b의 식으로 표현
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# x를 독립변수, y를 종속변수, b0를 절편, b1을 기울기라고 부른다.

# %%
#모의고사 성적으로 수능 점수 예측해보자!
import numpy as np
x = np.array([[74],[81],[94],[68],[64],[70],[83],[94],[71],[74]]) # 모의고사
y = np.array([71,78,90,68,66,72,89,92,78,80]) #수능

# %%
# 선형회귀 모델이 주어진 데이터에 적절한 모델인지 그림으로 확인한다.
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Q1. 직선에 대한 기울기와 절편을 대략적으로 계산하여 1차 함수로 표현해보자.
#
#
# ---
# y =

# %% [markdown]
# #2. 최소제곱법
# 근사적으로 구하려는 해와 실제 해의 오차 제곱의 합이 최소가 되는 모델을 구하는 방법

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #3. 모델 만들기(모델링)

# %%
#사이킷런으로 회귀모델 구현하기

# %%
#기울기
w =
#절편
b =
print("w= %.4f b= %.4f" )
print("정확도(R^2) = %.4f" )

# %% [markdown]
# > 만든 모델 : H(x) = 0.8246*x + 14.6615

# %%
#회귀선 그리기

# %%
#예측하기

# %%
#모의고사 점수 한 개 입력해서 수능 점수 예측하기

# %% [markdown]
# # 4. 다중 선형회귀 모델
# > 수능 시험 이전에 모의고사를 여러번 치른다. 여러번의 모의고사 점수로 예측해보자!
#
# ##### 여러 독립 변수에 의해 영향을 받는 경우
# ##### y = W1x1 + W2x2 + ...+ Wnxn + b의 식으로 표현

# %%
X = [[68,74,69],
     [83,81,76],
     [100,94,84],
     [71,68,67],
     [63,64,66],
     [70,70,70],
     [77,83,90],
     [86,94,90],
     [76,71,77],
     [64,74,84]]
Y = np.array([71,78,90,68,66,72,89,92,78,80])

# %%
# 선형회귀 모델 구현하기

# %%
# 기울기와 절편 구하기

# %%
#예측하기

# %% [markdown]
# ## 실습1. 선형회귀 적용가능한 주제 -
#
# *  독립변수 -
# *  종속변수 -
#
# 데이터출처 :
