# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/datascience/blob/main/18.%20(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%20%EC%8B%9D%EC%9A%A9%EA%B0%80%EB%8A%A5%ED%95%9C%20%EB%AC%BC%20%EB%B6%84%EB%A5%98%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 물에 관련된 속성 데이터를 활용하여 식용가능한 물을 분류해보자!

# %% [markdown]
# 데이터 속성 참고
#
# https://www.kaggle.com/datasets/sooyoungher/uci-mushroom-dataset?resource=download

# %% [markdown]
# # 필요한 모듈 포함시키기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %% [markdown]
# ## 데이터 세트 불러오기
#
#
# *   ph - 수소 이온 농도 지수
# *   Hardness - 경도(비누를 침전시키는 물의 용량)
# *   Solids - 총 용해 고형물(ppm)
# *   Chloramine - 클로라민의 양
# *   Sulfate - 황산염의 양
# *   Conductivity - 전기 전도도
# *   Organic_carbon - 유기 탄소의 양
# *   Trihalomethanes - 트리할로메탄의 양
# *   Turbidity - 탁도(물의 혼탁한 정도)
# *   Potability - 식수 여부

# %%
data = pd.read_csv('')
data.head()

# %%
# 결측값이 있는 행 삭제하기
data.dropna(axis=0, inplace=True) #행 제거 axis = 0
data.info()

# %%
# 상관계수 출력하기

# %% [markdown]
# # 식용 가능한 물을 분류할 수 있는지 확인 가능한 그래프 출력
# > 상관도가 높은 특징(3개) :

# %%
#상관 관계 그래프 그리기
plt.figure(figsize=(8,8))
sns.pairplot(data=data,vars=[],hue='Potability')
plt.show()

# %% [markdown]
# #예측에 필요한 모듈 포함 시키기

# %% [markdown]
# ###서포트벡터머신
# - N차원 공간에서 각 클래스 간의 거리를 최대화하는 최적의 선 또는 초평면을 찾아 데이터를 분류하는 알고리
# - 분류를 위한 기준 선을 정의하는 모델이다. 그래서 분류되지 않은 새로운 점이 나타나면 어느 쪽에 속하는지 확인해서 분류 과제를 수행할 수 있게 된다.
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.model_selection import train_test_split
#서포트벡터머신 라이브러리 불러오기

# %% [markdown]
# ##데이터 불러오기

# %%
x = data.iloc[:, :-1]
y = data['Potability']

# %% [markdown]
# 훈련 데이터와 테스트 데이터를 저장

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, shuffle=True)

# %% [markdown]
# 학습 모델 선언 및 학습

# %% [markdown]
# #학습된 모델로 테스트 데이터 예측

# %%
#정확도 측정하기

# %%
#입력한 값에 따라 결과 예측하기
my_model.predict([[7.1, 197.2, 501, 8.3, 400.5, 300.2, 10.8, 60.2, 1.7]])

# %% [markdown]
# # 혼동행렬(오차행렬) 그리기

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
Names = ['unpotable', 'potable']
y_pred = my_model.predict(x_test)
#오차행렬 그리기


sns.heatmap(data = cm_df, annot = True, fmt = '0.0f', cmap = 'Spectral')

# %% [markdown]
# 행 - 실제값, 열 - 예측값
# 현재 모든 예측을 먹을 수 없다고 판단하고 있음

# %% [markdown]
# #랜덤 포레스트 모델로 학습하기

# %% [markdown]
# 여러 개의 결정 트리를 조합하여 더 강력한 분류 모델을 구축하는 방법
#
# 결정트리에 배깅이라는 앙상블 학습을 적용한 모델
#
# 여러 개의 결정트리를 구성하고, 각 결정트리의 예측 결과를 다수결 방식으로 조합하여 최종 예측 결과를 결정

# %%
#라이브러리 불러오기

# %%
#모델 생성 및 학습

# %%
# 정확도 확인하기

# %%
# 오차 행렬

# %%
#입력한 값에 따라 결과 예측하기
RF.predict([[7.1, 197.2, 501, 8.3, 400.5, 300.2, 10.8, 60.2, 1.7]])
