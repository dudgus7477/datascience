# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/datascience/blob/main/19.%20(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%20%EB%B9%84%EC%A7%80%EB%8F%84%ED%95%99%EC%8A%B5_%EA%B5%B0%EC%A7%91%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### 우리의 제품 포트폴리오와 지역의 관계

# %% [markdown]
# # 필요한 모듈 포함시키기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 데이터 세트 불러오기

# %% [markdown]
# - Customer ID : 고객 번호
# - ZipCode : 우편 번호
# - Product : 제품번호
# #### 우편번호와 제품번호는 군집 분석 결과를 해석할 때 사용
# #### 산 횟수와 반품한 횟수로 군집화

# %% [markdown]
# # k-means 알고리즘
# #### 머신러닝 비지도학습에 속하는 알고리즘으로 데이터를 k개의 군집으로 묶는다.
# - 각 군집의 평균(mean)을 활용하여 k개의 군집으로 묶는다는 의미
# - 가깝게 위치하는 데이터를 비슷한 특성을 지닌 데이터로 여기고 같은 군집으로 군집화

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn import preprocessing

# %%
#원본 데이터 그대로 유지하기
processed_data = data.copy()

# %%
#정규화
scaler = preprocessing.MinMaxScaler()
processed_data[['ItemsBought', 'ItemsReturned']] = scaler.fit_transform(processed_data[['ItemsBought', 'ItemsReturned']])

# %%
plt.figure(figsize = (10, 10))

# %%
# K 값을 늘려가며 반복 테스트
for i in range(1, 7):
  # 클러스터 생성

  # 2행 3열을 가진 서브플롯 추가 (인덱스 = i)

  #간격 조절
  plt.tight_layout()
  # 서브플롯의 라벨링

  plt.xlabel('ItemsBought')
  plt.ylabel('ItemsReturned')
  # 클러스터링 그리기

plt.show()

# %% [markdown]
# #### K가 3, 4일때 군집화가 잘 됨.
# ##### 1. 제품을 많이 사고 유지하는 고객군
# ##### 2. 재품을 많이 사나 환불을 조금 하는 고객군
# ##### 3. 제품을 많이 안사고 환불은 많이 하는 고객군

# %% [markdown]
# #1. 각 군집과 제품 id의 관계

# %%
# K = 3으로 클러스터링


# 클러스터링 생성



# 제품과 클러스터 id로 데이터에 범례(주석) 달기
for index, c_id, bought, returned, zip_code, product in processed_data.itertuples():


plt.xlabel('ItemsBought')
plt.ylabel('ItemsReturned')
plt.show()

# %% [markdown]
# ##### Clu1인 제품 2435이 많이 안팔릴 뿐만 아니라 환불이 발생
# ##### 현재 그래프 상에는 데이터가 정규화되었기 때문에 면밀히 파악하기 어려우니 원래 데이터로 돌아가서 해당 제품을 찾아보자.

# %%
# 클러스터 1로 분류된 데이터를 추출해보자

# %% [markdown]
# #2. 각 군집과 지역의 관계 살펴보기
# ##### 지역마다 마케팅 활동에 대해 인사이트를 얻어보자!

# %%
plt.scatter(data['ItemsBought'], data['ItemsReturned'], c=cluster_ids)

# 우편번호로 범례달기
for (index, c_id, bought, returned, zip_code, product) in data.itertuples():

plt.xlabel('ItemsBought')
plt.ylabel('ItemsReturned')

plt.show()

# %% [markdown]
# #### 결론
# 1.
# 2.
