# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/datascience/blob/main/11.%20(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%20%EC%83%81%EA%B4%80%EA%B4%80%EA%B3%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. 들어가기 전에, 한글 폰트 설정해주기
#
# #### 코랩에서 한글 폰트 설정
# 1) 한글 폰트 코드 실행
#
# ```
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# ```
#
# 2) 런타임 - 런타임 다시시작
#
# 3) 글꼴 지정 명령어
#
# ```
# plt.rc('font', family='NanumGothic')
# ```

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# #1. 상관관계
# ### : 한 변수의 변화에 따른 다른 변수의 변화 정도와 방향을 측정하는 분석 기법
#
#
# >목표 : 신장과 체력측정간의 관계 분석
#
# ######하위목표1. 키가 크면 악력이 셀까?

# %% [markdown]
# # 2. 상관계수
# ### : 변수 사이의 관계 정도와 방향을 하나의 수치로 요약해 주는 통계치
# ##### -1에서 1사이의 값을 가지며, 절대값이 클수록 두 변수간의 상관관계가 높다.

# %% [markdown]
# > 데이터 출처 : 문화빅데이터플랫폼-국민체육진흥공단
# #####https://www.bigdata-culture.kr/bigdata/user/data_market/detail.do?id=b3924850-aa65-11ec-8ee4-95f65f846b27

# %%
#csv 파일 파이썬으로 읽어오기
import pandas as pd

df = pd.read_csv('.csv')
df.head()

# %% [markdown]
# ☝️잠시만 살펴봅시다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 결측값 개수 확인

# %%
# 결측값이 있는 행 삭제하기

# %% [markdown]
# > corr() : 인자로 전달된 데이터 집합과의 상관계수를 구하는 함수
# ex) 종류 - 피어슨, 스피어만, 켄달 상관계수 등등

# %%
#상대악력과 다른 속성 간 상관관계

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['연령대'] = le.fit_transform(df['연령대'])
df['성별'] = le.fit_transform(df['성별'])

# %%
#상대악력과 다른 속성 간 상관관계

# %%
#상대악력과 키의 상관관계
print("피어슨 상관계수 : ", )

# %% [markdown]
# # 3. 히트맵
# ##### : 열을 뜻하는 히트(heat)와 지도를 뜻하는 맵(map)을 결합시킨 단어로, 데이터의 값을 색상으로 변환시켜 분포 형태를 보여주는 것

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('font', family='NanumGothic')

# %%
# 상대악력과 신장 분포 확인하기

# %%
#상대악력과 가장 관련이 높은 것은?

# %%
#성별마다 특성이 다르지 않을까?

# %% [markdown]
# ### 2) 하위목표1 결과 분석
# ### - 체지방률이 높은 사람일수록 상대악력이 약하다
# ### - 신장과는 의미있는 연관성은 없어보인다.
# ### - http://mdon.co.kr/mobile/article.html?no=33076
# ### 실제 뉴스 기사를 보면 상대악력이 약할수록 당뇨병에 걸릴 확률이 높다는 것을 확인한 결과 체지방률과 관련성이 높다는 결과를 얻을 수 있다.

# %% [markdown]
# ##하위목표 2 :
# ### 1) 알고리즘 작성

# %% [markdown]
# ### 2) 하위목표2 결과 분석
# ### -
# ### -
