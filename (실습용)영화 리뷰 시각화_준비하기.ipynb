# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/datascience/blob/main/(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%EC%98%81%ED%99%94%20%EB%A6%AC%EB%B7%B0%20%EC%8B%9C%EA%B0%81%ED%99%94_%EC%A4%80%EB%B9%84%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 자연어 전처리 기법을 활용하여 영화 리뷰를 워드클라우드로 시각화해보자!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#코엔엘파이 설치

# %% [markdown]
# ### 1. 형태소 토큰화하기
# ![image.png](data:image/png;base64,...)

# %%
#Okt분석기 사용
from konlpy.tag import Okt
okt = Okt()

# %%
#morphs()
# Out:
# ['데이터', '과학', '과', '머신', '러닝']

# %%
#phrases()
# Out:
# ['달이']

# %%
#pos()
# Out:
# [('달이', 'Noun'), ('참', 'Verb'), ('예쁘다고', 'Adjective')]
# ['달이/Noun', '참/Verb', '예쁘다고/Adjective']

# %% [markdown]
# ####실습
# 직접 입력한 내용을 형태소분석하려면?

# %% [markdown]
# ###2.빈도수 추출하기
# collections : 동일한 값의 자료가 몇 개인지 파악하는데 사용하는 모듈
#
#
# ---
#
#
# counter() : 동일한 값의 빈도수
#
# ---
#
#
# most_common(n):가장 빈도 수가 많은 순서대로 n개 추출

# %% [markdown]
# #워드클라우드

# %%
#워드클라우드 설치

# %%
#한글 폰트 설치
! apt-get install fonts-nanum
font_path='/usr/share/fonts/truetype.nanum/NanumBarunGothic.ttf'

# %%
#text 가져오기

# %%
#워드클라우드 시각화
