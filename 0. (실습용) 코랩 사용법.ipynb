# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/datascience/blob/main/0.%20(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%20%EC%BD%94%EB%9E%A9%20%EC%82%AC%EC%9A%A9%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #0. 코랩 사용법

# %% [markdown]
# ### 새노트 만들기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 제목 수정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 포트폴리오 제출할때 학번이름으로 수정필요

# %% [markdown]
# ### 코드 및 텍스트 작성하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 가운데에 마우스 커서 가져가면 생김
# #####프로그래밍 코드 쓸때는 +코드, 글 작성할 때는 +텍스트

# %% [markdown]
# ### 단축키 사용법
#
# > 실행 관련 단축키
# ##### Ctrl+Enter : 해당 셀을 실행
# ##### Ctrl + M + Z : 실행 취소

# %% [markdown]
# # 1. 출력명령어
# ### 출력 명령어 형식
#
#
# > print( 출력할 내용 )

# %%
# 숫자 출력 0304

# %%
# 문자 출력 3월 5일

# %% [markdown]
# ### 문자는 따옴표로 감싸주어야 함
# > print('문자')
#
# > print("문자")

# %%
# 문자는 따옴표로 감싸주어야 함

# %%
# 연산하여 출력하기

# %%
# 숫자라 하더라도 따옴표로 감싸면 문자로 인식

# %%
# ** 제곱


# 몫


# 나머지

# %% [markdown]
# ### 연결하여 출력하기
# > print(  ,  )
# <br/>
# > print(  +  )

# %%
# 콤마, 로 연결하여 출력하기

# %%
# 더하기 +로 연결하여 출력하기

# %%
# +는 문자열 붙이기만 가능

# %% [markdown]
# # 3. 입력명령어
# ### 입력명령어 형식
# > input('입력안내문')
# ######입력한 단어가 결과창에 뜸

# %% [markdown]
# ######입력받은 결과는 항상 문자열로 나타남.

# %% [markdown]
# ### 순차구조
#
# <img src='https://github.com/teacher-jiejie/allinone_AI/blob/images/66_%E1%84%89%E1%85%AE%E1%86%AB%E1%84%8E%E1%85%A1%E1%84%80%E1%85%AE%E1%84%8C%E1%85%A9.png?raw=true' width=600>

# %%
print('---000 웹사이트 회원가입 ---')
# Out:
# ---000 웹사이트 회원가입 ---

# %% [markdown]
# ####실습1. 환영 문구만들기

# %%
#위의 코드를 추가해서 아래처럼 출력되도록 만들어봅시다!
#~(내가 입력한 아이디)님 가입을 환영합니다.
